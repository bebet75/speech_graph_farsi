# %%
# This Python file uses the following encoding: utf-8
from classifier import *
from data_to_feature import *
from feature_extract import *
from Plots import *
import Plots
from visualizer import *
from forming_xy import *
from POStag import *
import pandas as pd
import numpy as np
from parsivar import POSTagger
from parsivar import Tokenizer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\irantech24\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\irantech24\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\irantech24\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\irantech24\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\irantech24\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\irantech24\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\irantech24\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\irantech24\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# This Python file uses the following encoding: utf-8
from classifier import *
from data_to_feature import *
from feature_extract import *
from Plots import *
from visualizer import *
from forming_xy import *

X_features = [
    'seq_ad',
    'seq_ns',
    'seq_awd',
    'seq_gd',
    'seq_aspl',
    'seq_cc',
    'seq_lq',
    'seq_lscc',
    'seq_diameter',
    'seq_triangles',
    'seq_ne',
    'seq_nn',
    'cooc_ad',
    'cooc_awd',
    'cooc_gd',
    'cooc_aspl',
    'cooc_cc',
    'cooc_lq',
    'cooc_diameter',
    'cooc_nn',
    'cooc_ne',
    'cooc_ns']

classifiers = [
    KNeighborsClassifier(5),
    SVC(kernel="linear", C=0.025),
    GaussianProcessClassifier(1.0 * RBF(1.0)),
    DecisionTreeClassifier(max_depth=8),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
    MLPClassifier(alpha=0.2, max_iter=1000, hidden_layer_sizes=(128,)),
    MLPClassifier(alpha=0.2, max_iter=1000, hidden_layer_sizes=(64,)),
    MLPClassifier(alpha=0.2, max_iter=1000, hidden_layer_sizes=(256,)),
    MLPClassifier(alpha=0.2, max_iter=1000, hidden_layer_sizes=(32,64)),
    LogisticRegression(solver='newton-cg', random_state=0),
    LogisticRegression(penalty='l1', solver='liblinear', random_state=0, max_iter = 200),
    LogisticRegression(random_state=0),
    LogisticRegression(penalty='l2', random_state=0)
]

speech_pts = 'speech-pts.xlsx'
Speech_controls = 'Speech-controls.xlsx'
patients_info = 'patients_info.xlsx'
dir = 'features_mw.csv'

'''
# visualize
test_string = "You should be careful with words which second form is the same as other verb's infinitive. My last unlucky example is fell. WordNetLemmatizer does not convert it into 'fall' because there is actually a verb 'to fell'. Another example is 'felt'."
visualizer(test_string, language = 'english')
'''


# our data
seq_df = our_data_to_feature(speech_pts,Speech_controls,patients_info)
X, Y, features_df = forming_xy(seq_df,X_features)
classifier_full(X, Y, classifiers)
# Out:
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# Your list must have at least 400 words excluding preposition
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:98: RuntimeWarning: Edge directions are ignored for maximal clique calculation at src/cliques/maximal_cliques.c:269
#   seq_lq = len(g_seq.largest_cliques()) + seq_lq
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\feature_extract.py:103: RuntimeWarning: Edge directions are ignored for clique calculations at src/cliques/cliquer_wrapper.c:57
#   seq_triangles = len(g_seq.cliques(max=3, min=3)) + seq_triangles
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
#    subject_id PANSS diagnosis  age  education  word_count  Preposition ratio  \
# 0          s1  62.0    Schizo   22       14.0        1173           4.624893
# 1         s14  46.0    Schizo   59        8.0        1236           4.753236
# 2         s16  74.0    Schizo   35        NaN         319           5.250784
# 3         s19  96.0    Schizo   36        5.0         853           4.777257
# 4         s23  73.0    Schizo   52       12.0        1601           4.590881
# 5         s24  88.0    Schizo   61       12.0        1753           5.134056
# 6         s27  75.0    Schizo   31        9.0        3381           1.937297
# 7          s3  64.0    Schizo   61        8.0         946           3.594080
# 8         s31  46.0    Schizo   40       12.0        1460           4.520548
# 9         s33  64.0    Schizo   48       12.0         874           4.147597
# 10        s35  55.0    Schizo   64       11.0        2123           2.237400
# 11        s36  58.0    Schizo   41       11.0         794           3.400504
# 12        s37  39.0    Schizo   51        9.0        1466           3.308322
# 13         s4  84.0    Schizo   53       10.0        2170           2.396313
# 14        s42  80.0    Schizo   31       16.0        1351           3.571429
# 15        s43  91.0    Schizo   46       12.0         495           3.787879
# 16        s44   nan   Control   24       15.0         558           1.075269
# 17        s45   nan   Control   27       18.0         984           1.397358
# 18        s46   nan   Control   28       19.0        2660           1.118421
# 19        s47   nan   Control   29       11.0         422           2.428910
# 20        s48   nan   Control   35       16.0         966           0.569358
# 21        s49   nan   Control   25       17.0         957           1.541275
# 22        s50   nan   Control   26       19.0         725           1.482759
# 23        s51   nan   Control   24       17.0         935           1.229947
# 24        s52   nan   Control   27       17.0        3436           1.600698
# 25        s53   nan   Control   28       18.0         871           1.521240
# 26        s54   nan   Control   25       17.0        1430           1.486014
# 27        s55   nan   Control   30       18.0         420           2.678571
# 28        s56   nan   Control   26       19.0        2434           1.396878
# 29        s57   nan   Control   27       16.0         850           1.735294
# 30        s58   nan   Control   31       18.0         803           2.085928
# 31        s59   nan   Control   28       19.0        1022           1.859100
# 32         s6  71.0    Schizo   35       12.0        1084           4.335793
# 33        s60   nan   Control   27       18.0        2108           1.743359
# 34        s61   nan   Control   28       18.0        3329           1.494443
# 35        s62   nan   Control   31       23.0         986           1.445233
# 36        s63   nan   Control   28       19.0        1604           1.262469
# 37        s64   nan   Control   28       18.0        2827           0.928546
# 38        s65   nan   Control   26       18.0         634           2.523659
# 39        s66   nan   Control   27       19.0        2490           1.224900
# 40        s67   nan   Control   27       19.0        3080           1.785714
# 41        s68   nan   Control   27       19.0        2236           1.699463
# 42        s69   nan   Control   40       23.0        3497           2.087504
# 43         s7   NaN    Schizo   27        9.0         588           5.442177
# 44        s70   nan   Control   28       18.0         719           2.051460
# 45        s71   nan   Control   29       19.0         489           2.709611
# 46        s72   nan   Control   26       16.0         698           1.862464
# 47        s73   nan   Control   32       18.0        3555           1.561181
# 48        s75  78.0    Schizo   34       11.0        2730           2.216117
# 49        s76  68.0    Schizo   40       12.0         751           2.762983
# 50        s79  87.0    Schizo   48       12.0         585           3.247863
# 51        s8   80.0    Schizo   39       10.0        2542           3.353659
# 52        s80  81.0    Schizo   21       15.0        2459           2.440016
# 53        s81  68.0    Schizo   43       11.0         717           4.218968
#
#     Preposition  sentence_count      seq_nn  ...     cooc_nn   cooc_ne  \
# 0          5425             217  162.666667  ...  310.222222   12020.0
# 1          5875             235  182.700000  ...  398.700000   13828.5
# 2          1675              67    0.000000  ...    0.000000       0.0
# 3          4075             163  134.166667  ...  205.000000    4367.5
# 4          7350             294  159.714286  ...  427.142857   23270.0
# 5          9000             360  163.333333  ...  455.466667   24269.0
# 6          6550             262  167.419355  ...  742.258065  269940.0
# 7          3400             136  156.000000  ...  288.857143    8937.0
# 8          6600             264  149.416667  ...  387.750000   18557.0
# 9          3625             145  170.833333  ...  282.500000    7035.0
# 10         4750             190  188.526316  ...  641.368421   88650.0
# 11         2700             108  147.200000  ...  236.800000    6324.0
# 12         4850             194  160.416667  ...  412.500000   27819.0
# 13         5200             208  206.526316  ...  682.105263   87579.0
# 11       3.200000  17.091892
# 12       4.583333  20.606667
# 13       4.736842  25.607895
# 14       3.636364  18.014580
# 15       2.000000   8.219251
# 16       2.666667  38.014925
# 17       3.428571  42.871389
# 18       3.833333  55.937891
# 19       2.000000  10.925581
# 20       2.571429  78.083624
# 21       4.285714  30.802139
# 22       2.400000  27.511821
# 23       2.571429  38.327526
# 24       3.875000  40.941244
# 25       3.333333  31.804029
# 26       2.750000  35.839069
# 27       2.000000   9.752577
# 28       3.818182  41.361101
# 29       3.333333  23.727545
# 30       3.333333  21.180089
# 31       3.500000  27.652574
# 32       4.375000  11.742686
# 33       3.789474  32.158616
# 34       3.870968  47.324811
# 35       2.571429  30.591733
# 36       3.714286  43.052881
# 37       2.884615  62.732282
# 38       3.000000  19.769388
# 39       2.863636  48.738129
# 40       3.857143  39.322530
# 41       3.800000  37.289209
# 42       3.875000  31.387119
# 43       4.000000   6.844804
# 44       4.000000  20.171779
# 45       2.500000   9.982063
# 46       3.000000  21.182796
# 47       3.878788  45.040826
# 48       4.800000  35.719064
# 49       3.200000  15.754286
# 50       2.666667  12.019254
# 51       4.782609  24.317951
# 52       4.772727  28.074686
# 53       4.800000  11.189226
#
# [54 rows x 31 columns]
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\neighbors\_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# mean {KNeighborsClassifier(): 0.8127272727272726, SVC(C=0.025, kernel='linear'): 0.869090909090909, GaussianProcessClassifier(kernel=1**2 * RBF(length_scale=1)): 0.8981818181818183, DecisionTreeClassifier(max_depth=8): 0.8327272727272726, RandomForestClassifier(max_depth=5, max_features=1, n_estimators=10): 0.8163636363636363, MLPClassifier(alpha=0.2, hidden_layer_sizes=(128,), max_iter=1000): 0.8963636363636366, MLPClassifier(alpha=0.2, hidden_layer_sizes=(64,), max_iter=1000): 0.8927272727272727, MLPClassifier(alpha=0.2, hidden_layer_sizes=(256,), max_iter=1000): 0.8745454545454545, MLPClassifier(alpha=0.2, hidden_layer_sizes=(32, 64), max_iter=1000): 0.92, LogisticRegression(random_state=0, solver='newton-cg'): 0.9181818181818183, LogisticRegression(max_iter=200, penalty='l1', random_state=0,
#                    solver='liblinear'): 0.8854545454545453, LogisticRegression(random_state=0): 0.901818181818182, LogisticRegression(random_state=0): 0.8963636363636364}
# max {KNeighborsClassifier(): 0.9245283018867925, SVC(C=0.025, kernel='linear'): 0.9433962264150944, GaussianProcessClassifier(kernel=1**2 * RBF(length_scale=1)): 1.0, DecisionTreeClassifier(max_depth=8): 1.0, RandomForestClassifier(max_depth=5, max_features=1, n_estimators=10): 1.0, MLPClassifier(alpha=0.2, hidden_layer_sizes=(128,), max_iter=1000): 1.0, MLPClassifier(alpha=0.2, hidden_layer_sizes=(64,), max_iter=1000): 1.0, MLPClassifier(alpha=0.2, hidden_layer_sizes=(256,), max_iter=1000): 1.0, MLPClassifier(alpha=0.2, hidden_layer_sizes=(32, 64), max_iter=1000): 1.0, LogisticRegression(random_state=0, solver='newton-cg'): 0.9811320754716981, LogisticRegression(max_iter=200, penalty='l1', random_state=0,
#                    solver='liblinear'): 0.9811320754716981, LogisticRegression(random_state=0): 0.9811320754716981, LogisticRegression(random_state=0): 0.9811320754716981}

# 43    1268.0   6.844804
# 44    8220.0  20.171779
# 45    1113.0   9.982063
# 46    5910.0  21.182796
# 47  338144.0  45.040826
# 48  133500.0  35.719064
# 49    5514.0  15.754286
# 50    2497.0  12.019254
# 51   91168.0  24.317951
# 52   96043.5  28.074686
# 53    4154.0  11.189226
#
# [53 rows x 23 columns]

# %%
for feature_name in X_features:
    print('*************************************************')
    print(feature_name)
    x1 = features_df[features_df['diagnosis'] == "Schizo"][feature_name]
    x2 = features_df[features_df['diagnosis'] == "Control"][feature_name]
    print('mean_Schz', np.mean(x1))
    print('STD_Schz', np.std(x1))
    print('mean_Cntrl',np.mean(x2))
    print('STD_Cntrl',np.std(x2))
    print('ttest_ind', stats.ttest_ind(a=x1, b=x2, equal_var=True))
    print('kruskal', stats.kruskal(x1, x2))
    print('ranksums', stats.ranksums(x1, x2))
# Out:
# *************************************************
# seq_ad
# mean_Schz 21.176221652936423
# STD_Schz 15.458504215335518
# mean_Cntrl 23.3548856102403
# STD_Cntrl 19.589477907372416
# ttest_ind Ttest_indResult(statistic=-0.43045449689269016, pvalue=0.6686787414633448)
# kruskal KruskalResult(statistic=0.0012882447665560903, pvalue=0.9713683737239764)
# ranksums RanksumsResult(statistic=0.035892126803877704, pvalue=0.9713683737245369)
# *************************************************
# seq_ns
# mean_Schz 18.223404910836457
# STD_Schz 8.984687289810095
# mean_Cntrl 34.78257619672857
# STD_Cntrl 14.98137984889855
# ttest_ind Ttest_indResult(statistic=-4.603792945295993, pvalue=2.7884413841746214e-05)
# kruskal KruskalResult(statistic=16.015780998389687, pvalue=6.281669706566272e-05)
# ranksums RanksumsResult(statistic=-4.001972138632364, pvalue=6.281669706566241e-05)
# *************************************************
# seq_awd
# mean_Schz 145.78552705041787
# STD_Schz 183.14868358942906
# mean_Cntrl 198.22444558186362
# STD_Cntrl 242.48339610627303
# ttest_ind Ttest_indResult(statistic=-0.8485908094862039, pvalue=0.40007453640045576)
# kruskal KruskalResult(statistic=0.005152979066025409, pvalue=0.9427736042893772)
# ranksums RanksumsResult(statistic=0.07178425360775541, pvalue=0.942773604289393)
# *************************************************
# seq_gd
# mean_Schz 0.05859388741491495
# STD_Schz 0.045201867499834056
# mean_Cntrl 0.06086556957245405
# STD_Cntrl 0.05098675086433701
# ttest_ind Ttest_indResult(statistic=-0.1655744538297562, pvalue=0.8691464647650479)
# kruskal KruskalResult(statistic=0.10434782608697901, pvalue=0.7466731726289312)
# ranksums RanksumsResult(statistic=0.3230291412348993, pvalue=0.7466731726289577)
# *************************************************
# seq_aspl
# mean_Schz 4.6141823505290525
# STD_Schz 0.6992929089415593
# mean_Cntrl 4.545567746553488
# STD_Cntrl 0.7781856725991244
# ttest_ind Ttest_indResult(statistic=0.3259928170367095, pvalue=0.7457636821865179)
# kruskal KruskalResult(statistic=0.011594202898578487, pvalue=0.9142524062609483)
# ranksums RanksumsResult(statistic=-0.1076763804116331, pvalue=0.9142524062610505)
# *************************************************
# seq_cc
# mean_Schz 0.054413143550328974
# STD_Schz 0.013800214290816841
# mean_Cntrl 0.04996750787666328
# STD_Cntrl 0.015220108034569423
# ttest_ind Ttest_indResult(statistic=1.0762032949899416, pvalue=0.2869011445692606)
# kruskal KruskalResult(statistic=1.3607085346215797, pvalue=0.24341472410991305)
# ranksums RanksumsResult(statistic=1.1664941211260254, pvalue=0.2434147241099166)
# *************************************************
# seq_lq
# mean_Schz 13.624611598776697
# STD_Schz 15.45622155319153
# mean_Cntrl 9.63166049428783
# STD_Cntrl 11.412890142764981
# ttest_ind Ttest_indResult(statistic=1.0610867818927583, pvalue=0.2936496555959741)
# kruskal KruskalResult(statistic=0.04638242146620089, pvalue=0.8294821434878656)
# ranksums RanksumsResult(statistic=0.2153527608232662, pvalue=0.8294922972792294)
# *************************************************
# seq_lscc
# mean_Schz 158.24079654493826
# STD_Schz 26.209881115931474
# mean_Cntrl 162.59533383672073
# STD_Cntrl 28.55659937068968
# ttest_ind Ttest_indResult(statistic=-0.559181805688695, pvalue=0.5784850713061769)
# kruskal KruskalResult(statistic=0.9742743835919943, pvalue=0.3236164685443772)
# ranksums RanksumsResult(statistic=-0.9870334871066367, pvalue=0.3236262224069667)
# *************************************************
# seq_diameter
# mean_Schz 12.50982837331777
# STD_Schz 2.397935314864495
# mean_Cntrl 12.191955473667063
# STD_Cntrl 2.3577110530139427
# ttest_ind Ttest_indResult(statistic=0.4736721425016312, pvalue=0.6377551956407264)
# kruskal KruskalResult(statistic=0.31973279223002377, pvalue=0.5717682712868518)
# ranksums RanksumsResult(statistic=0.5653009971610738, pvalue=0.5718690505787971)
# *************************************************
# seq_triangles
# mean_Schz 41.45205773172377
# STD_Schz 12.44209269232571
# mean_Cntrl 41.6986486189956
# STD_Cntrl 14.833291910963634
# ttest_ind Ttest_indResult(statistic=-0.06303380305463571, pvalue=0.9499859911599389)
# kruskal KruskalResult(statistic=0.011596072931304066, pvalue=0.9142455180972217)
# ranksums RanksumsResult(statistic=0.1076763804116331, pvalue=0.9142524062610505)
# *************************************************
# seq_ne
# mean_Schz 1944.108695652174
# STD_Schz 1386.6927103608298
# mean_Cntrl 2262.633333333333
# STD_Cntrl 1923.2982821762778
# ttest_ind Ttest_indResult(statistic=-0.6588245124002131, pvalue=0.5129721095891158)
# kruskal KruskalResult(statistic=0.07246668968865556, pvalue=0.787778567712103)
# ranksums RanksumsResult(statistic=-0.26919095102908275, pvalue=0.7877827433834246)
# *************************************************
# seq_nn
# mean_Schz 158.86349261317207
# STD_Schz 26.484767416551453
# mean_Cntrl 163.73734784610318
# STD_Cntrl 28.919845732167257
# ttest_ind Ttest_indResult(statistic=-0.618542759154729, pvalue=0.5389705404371175)
# kruskal KruskalResult(statistic=1.178872004146322, pvalue=0.27758575275685105)
# ranksums RanksumsResult(statistic=-1.0857368358173005, pvalue=0.2775954387109154)
# *************************************************
# cooc_ad
# mean_Schz 139.56755672869824
# STD_Schz 164.49775233846734
# mean_Cntrl 275.3018509922489
# STD_Cntrl 255.8298588350484
# ttest_ind Ttest_indResult(statistic=-2.1750075997838487, pvalue=0.03429094228375563)
# kruskal KruskalResult(statistic=4.484380032206133, pvalue=0.03420595081773424)
# ranksums RanksumsResult(statistic=-2.1176354814287843, pvalue=0.03420595081773452)
# *************************************************
# cooc_awd
# mean_Schz 251.7455110455499
# STD_Schz 373.3887164706639
# mean_Cntrl 538.1508539857855
# STD_Cntrl 543.6305169627017
# ttest_ind Ttest_indResult(statistic=-2.123984059028202, pvalue=0.038541901178516746)
# kruskal KruskalResult(statistic=5.276650563607092, pvalue=0.02161328732952512)
# ranksums RanksumsResult(statistic=-2.297096115448173, pvalue=0.02161328732952516)
# *************************************************
# cooc_gd
# mean_Schz 0.2557998037868793
# STD_Schz 0.21397002928692985
# mean_Cntrl 0.43123032095033664
# STD_Cntrl 0.27957401276583976
# ttest_ind Ttest_indResult(statistic=-2.452302177466653, pvalue=0.01765663537378353)
# kruskal KruskalResult(statistic=7.054428341384863, pvalue=0.007906953835613493)
# ranksums RanksumsResult(statistic=-2.65601738348695, pvalue=0.007906953835613486)
# *************************************************
# cooc_aspl
# mean_Schz 2.0086362598657392
# STD_Schz 0.26162527853775897
# mean_Cntrl 1.6968981246986299
# STD_Cntrl 0.2736942277013959
# ttest_ind Ttest_indResult(statistic=4.109051409169735, pvalue=0.00014423117355220235)
# kruskal KruskalResult(statistic=18.705636070853473, pvalue=1.5253097676063953e-05)
# ranksums RanksumsResult(statistic=4.325001279867263, pvalue=1.5253097676064007e-05)
# *************************************************
# cooc_cc
# mean_Schz 0.2709481957073827
# STD_Schz 0.03292764961766731
# mean_Cntrl 0.32064532509175003
# STD_Cntrl 0.07120988272857665
# ttest_ind Ttest_indResult(statistic=-3.04326270178303, pvalue=0.003694149429877907)
# kruskal KruskalResult(statistic=8.452173913043481, pvalue=0.003646073608542366)
# ranksums RanksumsResult(statistic=-2.9072622711140936, pvalue=0.0036460736085423694)
# *************************************************
# cooc_lq
# mean_Schz 21.65278959793532
# STD_Schz 11.376947297923541
# mean_Cntrl 40.252408810181514
# STD_Cntrl 17.561713157128025
# ttest_ind Ttest_indResult(statistic=-4.3338401069902, pvalue=6.895576300540316e-05)
# kruskal KruskalResult(statistic=17.560208763900125, pvalue=2.7835234275478964e-05)
# ranksums RanksumsResult(statistic=-4.1904058043527215, pvalue=2.7845599615243964e-05)
# *************************************************
# cooc_diameter
# mean_Schz 4.232653656386409
# STD_Schz 0.7935338913375892
# mean_Cntrl 3.2435220957122484
# STD_Cntrl 0.6309160904843455
# ttest_ind Ttest_indResult(statistic=4.958165687028933, pvalue=8.268858400173806e-06)
# kruskal KruskalResult(statistic=18.412788618200018, pvalue=1.7786026953841495e-05)
# ranksums RanksumsResult(statistic=4.289109153063385, pvalue=1.7939119969495125e-05)
# *************************************************
# cooc_nn
# mean_Schz 386.1312157845104
# STD_Schz 178.11910355959603
# mean_Cntrl 456.51493202008794
# STD_Cntrl 266.66488085202957
# ttest_ind Ttest_indResult(statistic=-1.071845736776131, pvalue=0.2888353518118549)
# kruskal KruskalResult(statistic=0.5152979066022851, pvalue=0.4728543827539248)
# ranksums RanksumsResult(statistic=-0.717842536077554, pvalue=0.4728543827539382)
# *************************************************
# cooc_ne
# mean_Schz 41623.67391304348
# STD_Schz 61592.868929702345
# mean_Cntrl 99277.85
# STD_Cntrl 115385.26299482891
# ttest_ind Ttest_indResult(statistic=-2.129542551191428, pvalue=0.03805742346975423)
# kruskal KruskalResult(statistic=2.90660225442835, pvalue=0.08821754900866792)
# ranksums RanksumsResult(statistic=-1.7048760231841908, pvalue=0.08821754900866811)
# *************************************************
# cooc_ns
# mean_Schz 18.223404910836457
# STD_Schz 8.984687289810095
# mean_Cntrl 34.78257619672857
# STD_Cntrl 14.98137984889855
# ttest_ind Ttest_indResult(statistic=-4.603792945295993, pvalue=2.7884413841746214e-05)
# kruskal KruskalResult(statistic=16.015780998389687, pvalue=6.281669706566272e-05)
# ranksums RanksumsResult(statistic=-4.001972138632364, pvalue=6.281669706566241e-05)

# %%
for feature_name in X_features:
    print('*************************************************')
    print(feature_name)
    Stats(features_df, feature_name)
    print('*************************************************')
# Out:
# *************************************************
# seq_ad
# mean_Schz 21.176221652936423
# STD_Schz 15.458504215335518
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\test2.ipynb Cell 5 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/e%3A/Work/umind/project%20speech%20graph/roozbeh/Umind_CP/Umind_CP/Roozbeh1/final/test2.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> print('*************************************************')
#       <a href='vscode-notebook-cell:/e%3A/Work/umind/project%20speech%20graph/roozbeh/Umind_CP/Umind_CP/Roozbeh1/final/test2.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> print(feature_name)
# ----> <a href='vscode-notebook-cell:/e%3A/Work/umind/project%20speech%20graph/roozbeh/Umind_CP/Umind_CP/Roozbeh1/final/test2.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> Stats(features_df, feature_name)
#       <a href='vscode-notebook-cell:/e%3A/Work/umind/project%20speech%20graph/roozbeh/Umind_CP/Umind_CP/Roozbeh1/final/test2.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> print('*************************************************')
#
# File e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\Plots.py:151, in Stats(features_df, feature_name)
#     149 print('mean_Schz', np.mean(x1))
#     150 print('STD_Schz', np.std(x1))
# --> 151 print(np.mean('mean_Cntrl', x2))
#     152 print(np.std('STD_Cntrl', x2))
#     153 print('ttest_ind', stats.ttest_ind(a=x1, b=x2, equal_var=True))
#
# File <__array_function__ internals>:180, in mean(*args, **kwargs)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3474, in mean(a, axis, dtype, out, keepdims, where)
#    3471     else:
#    3472         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3474 return _methods._mean(a, axis=axis, dtype=dtype,
#    3475                       out=out, **kwargs)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:167, in _mean(a, axis, dtype, out, keepdims, where)
#     163 arr = asanyarray(a)
#     165 is_float16_result = False
# --> 167 rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#     168 if rcount == 0 if where is True else umr_any(rcount == 0, axis=None):
#     169     warnings.warn("Mean of empty slice.", RuntimeWarning, stacklevel=2)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:76, in _count_reduce_items(arr, axis, keepdims, where)
#      74     items = nt.intp(1)
#      75     for ax in axis:
# ---> 76         items *= arr.shape[mu.normalize_axis_index(ax, arr.ndim)]
#      77 else:
#      78     # TODO: Optimize case when `where` is broadcast along a non-reduction
#      79     # axis and full sum is more excessive than needed.
#      80
#      81     # guarded to protect circular imports
#      82     from numpy.lib.stride_tricks import broadcast_to
#
# File c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:191, in _coerce_method.<locals>.wrapper(self)
#     189 if len(self) == 1:
#     190     return converter(self.iloc[0])
# --> 191 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'int'>

# %%
'''
meaningful = ['seq_ns'***,
'cooc_ad',
'cooc_awd',
'cooc_gd',
'cooc_aspl',
'cooc_cc'**,
'cooc_lq'***-,
'cooc_diameter'***,
'cooc_nn',
'cooc_ne',
'cooc_ns'***]
'''

# %%
def Bar_plot(features_df, feature_name, name):
    # bar chart plot
    # Import data
    features_df1 = features_df[features_df['diagnosis']
                               == "Schizo"][[feature_name]]
    features_df2 = features_df[features_df['diagnosis']
                               == "Control"][[feature_name]]
    features_df3 = pd.concat(
        [features_df1, features_df2], axis=1, ignore_index=True, sort=False)
    features_df3 = features_df3.apply(lambda x: pd.Series(x.dropna().values))
    features_df3.rename(columns={0: 'Schizo'}, inplace=True)
    features_df3.rename(columns={1: 'Control'}, inplace=True)
    for n in range(1, features_df3.columns.shape[0] + 1):
        features_df3.rename(
            columns={
                f"data{n}": f"Experiment {n}"},
            inplace=True)
    features_df3.head()
    vals, names, xs = [], [], []
    for i, col in enumerate(features_df3.columns):
        vals.append(features_df3[col].dropna().values)
        names.append(col)
        # adds jitter to the data points - can be adjusted
        xs.append(
            np.random.normal(
                i / 2 + 0.5,
                0.04,
                features_df3[col].dropna().values.shape[0]))
    plt.figure(figsize=(5, 15))
    palette = ['r', 'g']
    for x, val, c in zip(xs, vals, palette):
        plt.scatter(x, val, alpha=0.4, color=c)

    ### '''## Set style options here #####
    sns.set_style(
        "darkgrid", {
            "grid.color": ".6", "grid.linestyle": ":"})  # "white","dark","darkgrid","ticks"
    boxprops = dict(linestyle='-', linewidth=1.5, color='#00145A')
    flierprops = dict(marker='o', markersize=1, linestyle='none')
    whiskerprops = dict(color='#00145A')
    capprops = dict(color='#00145A')
    medianprops = dict(linewidth=1.5, linestyle='-', color='#01FBEE')

    palette = ['#FF2709', '#09FF10']
    plt.boxplot(
        vals,
        positions=[
            0.5,
            1],
        widths=0.3,
        labels=names,
        notch=False,
        boxprops=boxprops,
        whiskerprops=whiskerprops,
        capprops=capprops,
        flierprops=flierprops,
        medianprops=medianprops,
        showmeans=False)
    plt.xlabel('Diagnosis', fontweight='normal', fontsize=14)
    plt.ylabel(name, fontweight='normal', fontsize=14)
    sns.despine(bottom=True)  # removes right and top axis lines
    # plt.axhline(y=65, color='#ff3300', linestyle='--', linewidth=1,
    # label='Threshold Value')
    plt.legend(
        bbox_to_anchor=(
            0.31,
            1.06),
        loc=2,
        borderaxespad=0.,
        framealpha=1,
        facecolor='white',
        frameon=True)
    plt.show()

# %%
def Dis_plot(features_df, feature_name, name):
    # Distributution plot
    sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

    # Import data
    x1 = features_df[features_df['diagnosis'] == "Schizo"][feature_name]
    x2 = features_df[features_df['diagnosis'] == "Control"][feature_name]
    kwargs = dict(hist_kws={'alpha': .6}, kde_kws={'linewidth': 2})

    plt.figure(figsize=(10, 7), dpi=80)
    sns.distplot(x1, color="orange", label="Schizo", **kwargs)
    sns.distplot(x2, color="dodgerblue", label="Control", **kwargs)
    # plt.xlim(50,75)
    plt.axvline(x=x1.mean(), color='orange', ls='--')
    plt.axvline(x=x2.mean(), color='blue', ls='--')
    plt.xlabel(name)
    plt.legend()

# %%
def plot_classification1(clf, X, y, list_of_features, names):
    title = ''
    feature1 = list_of_features[0]
    feature2 = list_of_features[1]
    sc = StandardScaler()
    
    # Divide dataset into training and testing parts
    X = X[list_of_features]
    X = pd.DataFrame(sc.fit_transform(X),index=X.index, columns=X.columns)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    #y=y['diagnosis']=="Schizo"
    # Fit the data with classifier.
    clf.fit(X_train, y_train)

    # Create color maps
    cmap_light = ListedColormap(['#AAFFAA','#FFAAAA'])
    cmap_bold = ListedColormap(['#00FF00','#FF0000'])

    h = .001  # step size in the mesh
    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, m_max]x[y_min, y_max].
    clearance1 = 0.1*(X[feature1].max()-X[feature1].min())
    x_min, x_max = X[feature1].min() - clearance1, X[feature1].max() + clearance1
    clearance2 = 0.1*(X[feature2].max()-X[feature2].min())
    y_min, y_max = X[feature2].min() - clearance2, X[feature2].max() + clearance2
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),np.arange(y_min, y_max, h))

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure()
    fig, ax = plt.subplots()
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)
    matplotlib.pyplot.xlabel(names[0])
    matplotlib.pyplot.ylabel(names[1])
    # Plot also the training points
    plt.scatter(X_train[feature1], X_train[feature2], c=y_train, cmap=cmap_bold, s=80)
    #plt.gca().legend(["Train1","Test1"])
    y_predicted = clf.predict(X_test)
    score1 = clf.score(X, y)
    score2 = clf.score(X_test, y_test)
    ax.scatter(X_test[feature1], X_test[feature2], c=y_predicted, alpha=0.5, cmap=cmap_bold,marker='^', s =80)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    #ax.legend(['g','r'],['Control','Schizo'],loc="lower right", title="Classes")
    title = 'Full Data Accuracy : ' + str(round(score1, 2)) + '  /  Test Data Accuracy : ' + str(round(score2, 2))
    plt.title(title)
    
    #plt.gca().legend(["Train2","Test2","Train1","Test1"])

# %%
#meaningful = ['seq_ns'***,'cooc_ad','cooc_awd','cooc_gd','cooc_aspl','cooc_cc'**,'cooc_lq'***-,'cooc_diameter'***,'cooc_nn','cooc_ne','cooc_ns'***]

# %%
clf = LogisticRegression(random_state=0)
list_of_features = ['cooc_cc','cooc_diameter']
names = ['Clustering Coefficient', 'Network Diameter']
plot_classification1(clf, X, Y, list_of_features, names)
# Out:
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
clf = LogisticRegression(random_state=0)
list_of_features = ['cooc_cc','cooc_ns']
names = ['Clustering Coefficient', 'Network Strength']
plot_classification1(clf, X, Y, list_of_features, names)
# Out:
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
clf = LogisticRegression(random_state=0)
list_of_features = ['cooc_diameter','cooc_ns']
names = ['Network Diameter', 'Network Strength']
plot_classification1(clf, X, Y, list_of_features, names)
# Out:
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
#'CON'***,'V_PR','PRO','ADV'***,'N'***,V_PA
feature_name = 'cooc_diameter'
name = 'Network Diameter'
Bar_plot(features_df, feature_name, name)
Dis_plot(features_df, feature_name, name)
#Stats(features_df, feature_name)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#'CON'***,'V_PR','PRO','ADV'***,'N'***,V_PA
feature_name = 'cooc_ns'
name = 'Network Strength'
Bar_plot(features_df, feature_name, name)
Dis_plot(features_df, feature_name, name)
#Stats(features_df, feature_name)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#'CON'***,'V_PR','PRO','ADV'***,'N'***,V_PA
feature_name = 'cooc_cc'
name = 'Clustering Coefficient'
Bar_plot(features_df, feature_name, name)
Dis_plot(features_df, feature_name, name)
#Stats(features_df, feature_name)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#'CON'***,'V_PR','PRO','ADV'***,'N'***,V_PA
feature_name = 'cooc_nn'
name = 'cooc_nn'
Bar_plot(features_df, feature_name, name)
Dis_plot(features_df, feature_name, name)
#Stats(features_df, feature_name)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
