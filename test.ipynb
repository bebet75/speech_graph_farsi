# %%
# This Python file uses the following encoding: utf-8
from classifier import *
from data_to_feature import *
from feature_extract import *
from Plots import *
from visualizer import *
from forming_xy import *
from POStag import *
import pandas as pd
import numpy as np
from parsivar import POSTagger
from parsivar import Tokenizer

# %%
seq_df = our_data_POS(speech_pts,Speech_controls,patients_info)
X, Y, features_df = forming_xy_POS(seq_df,X_features)

# %%
reg_plot(X,Y)
# Out:
#               precision    recall  f1-score   support
#
#        False      1.000     1.000     1.000         6
#         True      1.000     1.000     1.000         5
#
#     accuracy                          1.000        11
#    macro avg      1.000     1.000     1.000        11
# weighted avg      1.000     1.000     1.000        11
#
#    Variable  Coefficient  Coefficient_Abs
# 0  PRO_code    24.001923        24.001923
# 4       ADV   -12.876336        12.876336
# 7       CON   -10.858395        10.858395
# 5       PRO     8.619453         8.619453
# 2       ADJ    -7.987313         7.987313
# 3        PO    -7.984648         7.984648
# 6      V_PR     4.817023         4.817023
# 1         N    -1.794704         1.794704
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#        False      1.000     1.000     1.000         6
#         True      1.000     1.000     1.000         5
#
#     accuracy                          1.000        11
#    macro avg      1.000     1.000     1.000        11
# weighted avg      1.000     1.000     1.000        11
#
#    Variable  Coefficient  Coefficient_Abs
# 0  PRO_code     2.408057         2.408057
# 4       ADV    -1.398823         1.398823
# 7       CON    -0.624233         0.624233
# 5       PRO     0.512725         0.512725
# 2       ADJ    -0.055034         0.055034
# 1         N     0.000000         0.000000
# 3        PO     0.000000         0.000000
# 6      V_PR     0.000000         0.000000
#               precision    recall  f1-score   support
#
#        False      1.000     1.000     1.000         6
#         True      1.000     1.000     1.000         5
#
#     accuracy                          1.000        11
#    macro avg      1.000     1.000     1.000        11
# weighted avg      1.000     1.000     1.000        11
#
#    Variable  Coefficient  Coefficient_Abs
# 0  PRO_code     1.565171         1.565171
# 4       ADV    -1.007311         1.007311
# 7       CON    -1.004551         1.004551
# 5       PRO     0.701568         0.701568
# 1         N     0.367260         0.367260
# 3        PO    -0.309893         0.309893
# 2       ADJ    -0.286682         0.286682
# 6      V_PR     0.253091         0.253091
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#        False      1.000     1.000     1.000         6
#         True      1.000     1.000     1.000         5
#
#     accuracy                          1.000        11
#    macro avg      1.000     1.000     1.000        11
# weighted avg      1.000     1.000     1.000        11
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
clf = LogisticRegression(random_state=0)
list_of_features = ['PRO_code','ADV']
plot_classification_results(clf, X, Y, list_of_features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\Work\umind\project speech graph\roozbeh\Umind_CP\Umind_CP\Roozbeh1\final\test.ipynb Cell 4 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/e%3A/Work/umind/project%20speech%20graph/roozbeh/Umind_CP/Umind_CP/Roozbeh1/final/test.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> clf = LogisticRegression(random_state=0)
#       <a href='vscode-notebook-cell:/e%3A/Work/umind/project%20speech%20graph/roozbeh/Umind_CP/Umind_CP/Roozbeh1/final/test.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> list_of_features = ['PRO_code','ADV']
# ----> <a href='vscode-notebook-cell:/e%3A/Work/umind/project%20speech%20graph/roozbeh/Umind_CP/Umind_CP/Roozbeh1/final/test.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> plot_classification_results(clf, X, Y, list_of_features)
#
# NameError: name 'plot_classification_results' is not defined

# %%
feature_name = 'PO'
Bar_plot(features_df, feature_name)
Dis_plot(features_df, feature_name)
#Stats(features_df, feature_name)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
feature_name = 'PRO'
Bar_plot(features_df, feature_name)
Dis_plot(features_df, feature_name)
#Stats(features_df, feature_name)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
feature_name = 'ADJ'
Bar_plot(features_df, feature_name)
Dis_plot(features_df, feature_name)
#Stats(features_df, feature_name)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
feature_name = 'ADV'
Bar_plot(features_df, feature_name)
Dis_plot(features_df, feature_name)
#Stats(features_df, feature_name)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
feature_name = 'N'
Bar_plot(features_df, feature_name)
Dis_plot(features_df, feature_name)
#Stats(features_df, feature_name)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
feature_name = 'PO'
Bar_plot(features_df, feature_name)
Dis_plot(features_df, feature_name)
#Stats(features_df, feature_name)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
