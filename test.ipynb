# %%
# This Python file uses the following encoding: utf-8
from classifier import *
from data_to_feature import *
from feature_extract import *
from Plots import *
import Plots
from visualizer import *
from forming_xy import *
from POStag import *
import pandas as pd
import numpy as np
from parsivar import POSTagger
from parsivar import Tokenizer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\irantech24\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\irantech24\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\irantech24\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\irantech24\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\irantech24\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\irantech24\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\irantech24\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\irantech24\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
speech_pts = 'speech-pts.xlsx'
Speech_controls = 'Speech-controls.xlsx'
patients_info = 'patients_info.xlsx'
dir = 'features_mw.csv'
X_features = ['N','ADJ','PO','ADV','PRO','V_PR','CON','DELM','DET','V_PA','INT','PP','AR']
seq_df = our_data_POS(speech_pts,Speech_controls,patients_info)
X, Y, features_df = forming_xy_POS(seq_df,X_features)
# Out:
#            N PANSS diagnosis  age  education       ADJ        PO       ADV  \
# 0   0.390261  62.0    Schizo   22       14.0  0.078189  0.090535  0.074760
# 1   0.439310  46.0    Schizo   59        8.0  0.088966  0.082069  0.055862
# 2   0.408488  74.0    Schizo   35        NaN  0.111406  0.087533  0.127321
# 3   0.425651  96.0    Schizo   36        5.0  0.066914  0.100372  0.045539
# 4   0.434354  73.0    Schizo   52       12.0  0.099637  0.088739  0.050856
# 5   0.407321  88.0    Schizo   61       12.0  0.083998  0.082121  0.070389
# 6   0.391422  75.0    Schizo   31        9.0  0.090196  0.082108  0.066176
# 7   0.375415  64.0    Schizo   61        8.0  0.106312  0.093023  0.047342
# 8   0.396809  46.0    Schizo   40       12.0  0.084574  0.074468  0.080319
# 9   0.384201  64.0    Schizo   48       12.0  0.079892  0.088869  0.071813
# 10  0.421386  55.0    Schizo   64       11.0  0.077124  0.082712  0.065574
# 11  0.395301  58.0    Schizo   41       11.0  0.092952  0.089888  0.051073
# 12  0.400000  39.0    Schizo   51        9.0  0.084469  0.065940  0.058311
# 13  0.425101  84.0    Schizo   53       10.0  0.080604  0.092013  0.052632
# 14  0.427553  80.0    Schizo   31       16.0  0.093230  0.064133  0.081948
# 15  0.410256  91.0    Schizo   46       12.0  0.065705  0.054487  0.084936
# 16  0.336662   nan   Control   24       15.0  0.099857  0.072753  0.106990
# 17  0.382278   nan   Control   27       18.0  0.117300  0.075105  0.079325
# 18  0.368285   nan   Control   28       19.0  0.084790  0.049515  0.101618
# 19  0.394683   nan   Control   29       11.0  0.100204  0.079755  0.085890
# 20  0.371168   nan   Control   35       16.0  0.102734  0.109362  0.076222
# 21  0.418871   nan   Control   25       17.0  0.097002  0.072310  0.086420
# 22  0.356009   nan   Control   26       19.0  0.100907  0.071429  0.133787
# 23  0.348199   nan   Control   24       17.0  0.088336  0.089194  0.098628
# 24  0.379725   nan   Control   27       17.0  0.100884  0.084192  0.093765
# 25  0.365511   nan   Control   28       18.0  0.094658  0.099344  0.119025
# 26  0.360319   nan   Control   25       17.0  0.094641  0.061574  0.118016
# 27  0.383698   nan   Control   30       18.0  0.067594  0.071571  0.113320
# 28  0.349641   nan   Control   26       19.0  0.089292  0.102292  0.117687
# 29  0.392216   nan   Control   27       16.0  0.080838  0.065868  0.077844
# 30  0.380694   nan   Control   31       18.0  0.077007  0.081345  0.135575
# 9   0.000898  0.057451  3.254039
# 10  0.001118  0.019747  1.769747
# 11  0.001021  0.052094  2.757916
# 12  0.005450  0.043052  2.643052
# 13  0.001840  0.025028  1.913876
# 14  0.004157  0.030285  2.865202
# 15  0.004808  0.062500  3.004808
# 16  0.002853  0.015692  0.855920
# 17  0.002532  0.010970  1.160338
# 18  0.001618  0.029773  0.962783
# 19  0.012270  0.006135  2.096115
# 20  0.000000  0.007457  0.455675
# 21  0.001764  0.022046  1.300705
# 22  0.001134  0.006803  1.218821
# 23  0.001715  0.017153  0.986278
# 24  0.002455  0.015709  1.350025
# 25  0.001874  0.014058  1.241799
# 26  0.000570  0.013683  1.211517
# 27  0.000000  0.031809  2.236581
# 28  0.001026  0.021211  1.163189
# 29  0.002994  0.038922  1.472056
# 30  0.004338  0.030369  1.816703
# 31  0.002449  0.032653  1.551020
# 32  0.002259  0.035392  3.539157
# 33  0.003210  0.040530  1.474719
# 34  0.002982  0.016650  1.236332
# 35  0.004170  0.007506  1.188490
# 36  0.001050  0.028346  1.062992
# 37  0.002331  0.023310  0.764860
# 38  0.001370  0.032877  2.191781
# 39  0.001301  0.010081  0.991870
# 40  0.000540  0.016739  1.484881
# 41  0.002934  0.020169  1.393473
# 42  0.002438  0.023891  1.779620
# 43  0.006859  0.057613  4.389575
# 44  0.003571  0.008333  1.755952
# 45  0.000000  0.059028  2.300347
# 46  0.003429  0.025143  1.485714
# 47  0.002290  0.025424  1.271186
# 48  0.000898  0.022455  1.811377
# 49  0.001087  0.031522  2.255435
# 50  0.000000  0.039402  2.581522
# 51  0.005714  0.045714  2.706349
# 52  0.002533  0.027866  1.899937
# 53  0.000000  0.048533  3.414221

# %%
reg_plot(X,Y)
# Out:
#               precision    recall  f1-score   support
#
#        False      1.000     1.000     1.000         6
#         True      1.000     1.000     1.000         5
#
#     accuracy                          1.000        11
#    macro avg      1.000     1.000     1.000        11
# weighted avg      1.000     1.000     1.000        11
#
#    Variable  Coefficient  Coefficient_Abs
# 10      INT     4.935241         4.935241
# 7      DELM     4.679564         4.679564
# 6       CON    -4.630026         4.630026
# 3       ADV    -3.194410         3.194410
# 11       PP    -2.759410         2.759410
# 0         N     1.924195         1.924195
# 12       AR     1.892751         1.892751
# 5      V_PR     1.498227         1.498227
# 4       PRO     0.957547         0.957547
# 2        PO     0.864541         0.864541
# 9      V_PA    -0.805233         0.805233
# 1       ADJ     0.579625         0.579625
# 8       DET    -0.285270         0.285270
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#        False      1.000     1.000     1.000         6
#         True      1.000     1.000     1.000         5
#
#     accuracy                          1.000        11
#    macro avg      1.000     1.000     1.000        11
# weighted avg      1.000     1.000     1.000        11
#
#    Variable  Coefficient  Coefficient_Abs
# 10      INT     1.748463         1.748463
# 7      DELM     1.100627         1.100627
# 6       CON    -0.957148         0.957148
# 3       ADV    -0.666425         0.666425
# 11       PP    -0.251002         0.251002
# 12       AR     0.155301         0.155301
# 9      V_PA    -0.129774         0.129774
# 0         N     0.000000         0.000000
# 1       ADJ     0.000000         0.000000
# 2        PO     0.000000         0.000000
# 4       PRO     0.000000         0.000000
# 5      V_PR     0.000000         0.000000
# 8       DET     0.000000         0.000000
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#        False      1.000     1.000     1.000         6
#         True      1.000     1.000     1.000         5
#
#     accuracy                          1.000        11
#    macro avg      1.000     1.000     1.000        11
# weighted avg      1.000     1.000     1.000        11
#
#    Variable  Coefficient  Coefficient_Abs
# 6       CON    -0.959942         0.959942
# 10      INT     0.924746         0.924746
# 7      DELM     0.907592         0.907592
# 3       ADV    -0.738723         0.738723
# 0         N     0.641224         0.641224
# 12       AR     0.414563         0.414563
# 5      V_PR     0.395893         0.395893
# 11       PP    -0.392657         0.392657
# 9      V_PA    -0.380473         0.380473
# 4       PRO     0.322312         0.322312
# 8       DET    -0.137768         0.137768
# 1       ADJ     0.049766         0.049766
# 2        PO     0.040733         0.040733
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
#               precision    recall  f1-score   support
#
#        False      1.000     1.000     1.000         6
#         True      1.000     1.000     1.000         5
#
#     accuracy                          1.000        11
#    macro avg      1.000     1.000     1.000        11
# weighted avg      1.000     1.000     1.000        11
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
def plot_classification1(clf, X, y, list_of_features, names):
    title = ''
    feature1 = list_of_features[0]
    feature2 = list_of_features[1]
    sc = StandardScaler()
    
    # Divide dataset into training and testing parts
    X = X[list_of_features]
    X = pd.DataFrame(sc.fit_transform(X),index=X.index, columns=X.columns)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    #y=y['diagnosis']=="Schizo"
    # Fit the data with classifier.
    clf.fit(X_train, y_train)

    # Create color maps
    cmap_light = ListedColormap(['#AAFFAA','#FFAAAA'])
    cmap_bold = ListedColormap(['#00FF00','#FF0000'])

    h = .001  # step size in the mesh
    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, m_max]x[y_min, y_max].
    clearance1 = 0.1*(X[feature1].max()-X[feature1].min())
    x_min, x_max = X[feature1].min() - clearance1, X[feature1].max() + clearance1
    clearance2 = 0.1*(X[feature2].max()-X[feature2].min())
    y_min, y_max = X[feature2].min() - clearance2, X[feature2].max() + clearance2
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),np.arange(y_min, y_max, h))

    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)
    plt.figure()
    fig, ax = plt.subplots()
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)
    matplotlib.pyplot.xlabel(names[0])
    matplotlib.pyplot.ylabel(names[1])
    # Plot also the training points
    plt.scatter(X_train[feature1], X_train[feature2], c=y_train, cmap=cmap_bold, s=80)
    #plt.gca().legend(["Train1","Test1"])
    y_predicted = clf.predict(X_test)
    score1 = clf.score(X, y)
    score2 = clf.score(X_test, y_test)
    ax.scatter(X_test[feature1], X_test[feature2], c=y_predicted, alpha=0.5, cmap=cmap_bold,marker='^', s =80)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    #ax.legend(['g','r'],['Control','Schizo'],loc="lower right", title="Classes")
    title = 'Full Data Accuracy : ' + str(round(score1, 2)) + '  /  Test Data Accuracy : ' + str(round(score2, 2))
    plt.title(title)
    
    #plt.gca().legend(["Train2","Test2","Train1","Test1"])

# %%
for feature_name in X_features:
    print('*************************************************')
    print(feature_name)
    x1 = features_df[features_df['diagnosis'] == "Schizo"][feature_name]
    x2 = features_df[features_df['diagnosis'] == "Control"][feature_name]
    print('mean_Schz', np.mean(x1))
    print('STD_Schz', np.std(x1))
    print('mean_Cntrl',np.mean(x2))
    print('STD_Cntrl',np.std(x2))
    print('ttest_ind', stats.ttest_ind(a=x1, b=x2, equal_var=True))
    print('kruskal', stats.kruskal(x1, x2))
    print('ranksums', stats.ranksums(x1, x2))
# Out:
# *************************************************
# N
# mean_Schz 0.4105963974684905
# STD_Schz 0.018822945051419907
# mean_Cntrl 0.37173336937749807
# STD_Cntrl 0.028434613244488118
# ttest_ind Ttest_indResult(statistic=5.65381674591138, pvalue=6.741478415504389e-07)
# kruskal KruskalResult(statistic=20.801212121212103, pvalue=5.09507067388534e-06)
# ranksums RanksumsResult(statistic=4.560834586039284, pvalue=5.095070673885274e-06)
# *************************************************
# ADJ
# mean_Schz 0.08856176318531395
# STD_Schz 0.013355309855279881
# mean_Cntrl 0.09389977475641707
# STD_Cntrl 0.012147604658216866
# ttest_ind Ttest_indResult(statistic=-1.5062585154240873, pvalue=0.13805192095465793)
# kruskal KruskalResult(statistic=3.030303030303031, pvalue=0.0817227522986595)
# ranksums RanksumsResult(statistic=-1.7407765595569784, pvalue=0.08172275229865932)
# *************************************************
# PO
# mean_Schz 0.07652475131822421
# STD_Schz 0.014918061596156114
# mean_Cntrl 0.07957057666599675
# STD_Cntrl 0.015154970632900463
# ttest_ind Ttest_indResult(statistic=-0.72516806559855, pvalue=0.4715997880106717)
# kruskal KruskalResult(statistic=0.22090909090908895, pvalue=0.6383481080711453)
# ranksums RanksumsResult(statistic=-0.47000967108038416, pvalue=0.638348108071144)
# *************************************************
# ADV
# mean_Schz 0.06740484752583321
# STD_Schz 0.017870573331579244
# mean_Cntrl 0.10490955364912415
# STD_Cntrl 0.019717042629398177
# ttest_ind Ttest_indResult(statistic=-7.103456853620997, pvalue=3.3844656409225856e-09)
# kruskal KruskalResult(statistic=29.68757575757573, pvalue=5.075910356972294e-08)
# ranksums RanksumsResult(statistic=-5.448630631413343, pvalue=5.0759103569722064e-08)
# *************************************************
# PRO
# mean_Schz 0.05538715612332638
# STD_Schz 0.011070260042850333
# mean_Cntrl 0.0419958773986824
# STD_Cntrl 0.014026935397911595
# ttest_ind Ttest_indResult(statistic=3.7494889637840934, pvalue=0.0004464795676198357)
# kruskal KruskalResult(statistic=11.054848484848463, pvalue=0.0008845557425020367)
# ranksums RanksumsResult(statistic=3.3248832287538286, pvalue=0.0008845557425020264)
# *************************************************
# V_PR
# mean_Schz 0.06836874000354116
# STD_Schz 0.012704096714195793
# mean_Cntrl 0.059403176501961294
# STD_Cntrl 0.01163677159018291
# ttest_ind Ttest_indResult(statistic=2.6500299020016698, pvalue=0.010637590711957723)
# kruskal KruskalResult(statistic=5.360303030303044, pvalue=0.020600193805604454)
# ranksums RanksumsResult(statistic=2.3152328242107814, pvalue=0.020600193805604544)
# *************************************************
# CON
# mean_Schz 0.07005286279908625
# STD_Schz 0.014281388512380774
# mean_Cntrl 0.11460534406885027
# STD_Cntrl 0.019533423762753695
# ttest_ind Ttest_indResult(statistic=-9.176883404637657, pvalue=1.8520571625650493e-12)
# kruskal KruskalResult(statistic=34.824545454545444, pvalue=3.6079595578261794e-09)
# ranksums RanksumsResult(statistic=-5.901232536898156, pvalue=3.6079595578261695e-09)
# *************************************************
# DELM
# mean_Schz 0.023497806457524945
# STD_Schz 0.008721215270387689
# mean_Cntrl 0.006785868130433729
# STD_Cntrl 0.005265307922465445
# ttest_ind Ttest_indResult(statistic=8.53672142658999, pvalue=1.8234734796081417e-11)
# kruskal KruskalResult(statistic=33.80484848484846, pvalue=6.092683015236545e-09)
# ranksums RanksumsResult(statistic=5.814193708920308, pvalue=6.092683015236471e-09)
# *************************************************
# DET
# mean_Schz 0.020910693660624324
# STD_Schz 0.007594313799459367
# mean_Cntrl 0.02337307271621964
# STD_Cntrl 0.004669924921286732
# ttest_ind Ttest_indResult(statistic=-1.4360842558386901, pvalue=0.15696731482848145)
# kruskal KruskalResult(statistic=2.4546390180681685, pvalue=0.11717810456828476)
# ranksums RanksumsResult(statistic=-1.5666989036012806, pvalue=0.11718508719813801)
# *************************************************
# V_PA
# mean_Schz 0.060414320045277935
# STD_Schz 0.01965564046449778
# mean_Cntrl 0.07378961050863683
# STD_Cntrl 0.014211427946046514
# ttest_ind Ttest_indResult(statistic=-2.8443705155165486, pvalue=0.006348977656051752)
# kruskal KruskalResult(statistic=6.9093939393939365, pvalue=0.008574404954256308)
# ranksums RanksumsResult(statistic=-2.6285726049310374, pvalue=0.008574404954256277)
# *************************************************
# INT
# mean_Schz 0.010961586256947724
# STD_Schz 0.005243388499815396
# mean_Cntrl 0.0006928781543469621
# STD_Cntrl 0.000982162188330643
# ttest_ind Ttest_indResult(statistic=10.302637149919384, pvalue=3.6750534660421456e-14)
# kruskal KruskalResult(statistic=39.082668735453844, pvalue=4.0623425635128285e-10)
# ranksums RanksumsResult(statistic=6.197164552022843, pvalue=5.748938957028601e-10)
# *************************************************
# PP
# mean_Schz 0.0024579122792781284
# STD_Schz 0.00197974993679302
# mean_Cntrl 0.002373608938667444
# STD_Cntrl 0.00217582920882669
# ttest_ind Ttest_indResult(statistic=0.1444689234791376, pvalue=0.8856886709217837)
# kruskal KruskalResult(statistic=0.006144561068725162, pvalue=0.9375200148104863)
# ranksums RanksumsResult(statistic=-0.07833494518006402, pvalue=0.9375616206233207)
# *************************************************
# AR
# mean_Schz 0.03804621816399069
# STD_Schz 0.014713544168551928
# mean_Cntrl 0.021748985895930623
# STD_Cntrl 0.011796365012464085
# ttest_ind Ttest_indResult(statistic=4.4330949706256035, pvalue=4.8266064849115446e-05)
# kruskal KruskalResult(statistic=13.74818181818182, pvalue=0.00020902304396566192)
# ranksums RanksumsResult(statistic=3.707854071856364, pvalue=0.00020902304396566175)

# %%
#'CON'***,'V_PR','PRO','ADV'***,'N'***

# %%
clf = LogisticRegression(random_state=0)
list_of_features = ['CON','ADV']
names = ['Conjunction', 'Adverb']
plot_classification1(clf, X, Y, list_of_features, names)
# Out:
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
clf = LogisticRegression(random_state=0)
list_of_features = ['N','ADV']
names = ['Noun', 'Adverb']
plot_classification1(clf, X, Y, list_of_features, names)
# Out:
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
clf = LogisticRegression(random_state=0)
list_of_features = ['CON','N']
names = ['Conjunction', 'Noun']
plot_classification1(clf, X, Y, list_of_features, names)
# Out:
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
def Dis_plot(features_df, feature_name, name):
    # Distributution plot
    sns.set_style("darkgrid", {"grid.color": ".6", "grid.linestyle": ":"})

    # Import data
    x1 = features_df[features_df['diagnosis'] == "Schizo"][feature_name]
    x2 = features_df[features_df['diagnosis'] == "Control"][feature_name]
    kwargs = dict(hist_kws={'alpha': .6}, kde_kws={'linewidth': 2})

    plt.figure(figsize=(10, 7), dpi=80)
    sns.distplot(x1, color="orange", label="Schizo", **kwargs)
    sns.distplot(x2, color="dodgerblue", label="Control", **kwargs)
    # plt.xlim(50,75)
    plt.axvline(x=x1.mean(), color='orange', ls='--')
    plt.axvline(x=x2.mean(), color='blue', ls='--')
    plt.xlabel(name)
    plt.legend()

# %%
def Bar_plot(features_df, feature_name, name):
    # bar chart plot
    # Import data
    features_df1 = features_df[features_df['diagnosis']
                               == "Schizo"][[feature_name]]
    features_df2 = features_df[features_df['diagnosis']
                               == "Control"][[feature_name]]
    features_df3 = pd.concat(
        [features_df1, features_df2], axis=1, ignore_index=True, sort=False)
    features_df3 = features_df3.apply(lambda x: pd.Series(x.dropna().values))
    features_df3.rename(columns={0: 'Schizo'}, inplace=True)
    features_df3.rename(columns={1: 'Control'}, inplace=True)
    for n in range(1, features_df3.columns.shape[0] + 1):
        features_df3.rename(
            columns={
                f"data{n}": f"Experiment {n}"},
            inplace=True)
    features_df3.head()
    vals, names, xs = [], [], []
    for i, col in enumerate(features_df3.columns):
        vals.append(features_df3[col].dropna().values)
        names.append(col)
        # adds jitter to the data points - can be adjusted
        xs.append(
            np.random.normal(
                i / 2 + 0.5,
                0.04,
                features_df3[col].dropna().values.shape[0]))
    plt.figure(figsize=(5, 15))
    palette = ['r', 'g']
    for x, val, c in zip(xs, vals, palette):
        plt.scatter(x, val, alpha=0.4, color=c)

    ### '''## Set style options here #####
    sns.set_style(
        "darkgrid", {
            "grid.color": ".6", "grid.linestyle": ":"})  # "white","dark","darkgrid","ticks"
    boxprops = dict(linestyle='-', linewidth=1.5, color='#00145A')
    flierprops = dict(marker='o', markersize=1, linestyle='none')
    whiskerprops = dict(color='#00145A')
    capprops = dict(color='#00145A')
    medianprops = dict(linewidth=1.5, linestyle='-', color='#01FBEE')

    palette = ['#FF2709', '#09FF10']
    plt.boxplot(
        vals,
        positions=[
            0.5,
            1],
        widths=0.3,
        labels=names,
        notch=False,
        boxprops=boxprops,
        whiskerprops=whiskerprops,
        capprops=capprops,
        flierprops=flierprops,
        medianprops=medianprops,
        showmeans=False)
    plt.xlabel('Diagnosis', fontweight='normal', fontsize=14)
    plt.ylabel(name, fontweight='normal', fontsize=14)
    sns.despine(bottom=True)  # removes right and top axis lines
    # plt.axhline(y=65, color='#ff3300', linestyle='--', linewidth=1,
    # label='Threshold Value')
    plt.legend(
        bbox_to_anchor=(
            0.31,
            1.06),
        loc=2,
        borderaxespad=0.,
        framealpha=1,
        facecolor='white',
        frameon=True)
    plt.show()

# %%
#'CON'***,'V_PR','PRO','ADV'***,'N'***,V_PA
feature_name = 'N'
name = 'Noun'
Bar_plot(features_df, feature_name, name)
Dis_plot(features_df, feature_name, name)
#Stats(features_df, feature_name)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#'CON'***,'V_PR','PRO','ADV'***,'N'***,V_PA
feature_name = 'CON'
name = 'Conjunction'
Bar_plot(features_df, feature_name, name)
Dis_plot(features_df, feature_name, name)
#Stats(features_df, feature_name)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#'CON'***,'V_PR','PRO','ADV'***,'N'***,V_PA
feature_name = 'ADV'
name = 'Adverb'
Bar_plot(features_df, feature_name, name)
Dis_plot(features_df, feature_name, name)
#Stats(features_df, feature_name)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\irantech24\AppData\Roaming\Python\Python39\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
